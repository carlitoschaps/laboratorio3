# %%
import pandas as pd
import matplotlib.pyplot as plt
path = "/content/drive/MyDrive/conjunto de datos/carlitos - atenciones_abogadas_de_las_mujeres (4).csv"
df = pd.read_csv(path)
edad = df ["usuaria_edad"]
dist = edad.value_counts()
plt.bar(dist.index, dist.values)
plt.xlim(0, 100)
plt.show()
# Out:
# <ipython-input-7-63df1fc730f2>:4: DtypeWarning: Columns (14,19,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)

# %%
import pandas as pd
import matplotlib.pyplot as plt
path = "/content/drive/MyDrive/conjunto de datos/atenciones_abogadas_de_las_mujeres (4).csv"
df = pd.read_csv(path)
conteo = df["usuaria_estado_civil"].value_counts()
plt.barh( conteo.index, conteo)
plt.show()
# Out:
# <ipython-input-5-631f3022a712>:4: DtypeWarning: Columns (11,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)

# %% [markdown]
# # Sección nueva

# %%
import pandas as pd
import matplotlib.pyplot as plt
path = "/content/drive/MyDrive/conjunto de datos/carlitos - atenciones_abogadas_de_las_mujeres (4).csv"
df = pd.read_csv(path)
edad = df ["mes"]
dist = edad.value_counts()
plt.bar(dist.index, dist.values)
plt.xlim(0, 100)
plt.show()
# Out:
# <ipython-input-11-7cdb4bc98e30>:4: DtypeWarning: Columns (14,19,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)

# %% [markdown]
# # Sección nueva

# %%
import pandas as pd
import matplotlib.pyplot as plt
path = "/content/drive/MyDrive/conjunto de datos/carlitos - atenciones_abogadas_de_las_mujeres (4).csv"
df = pd.read_csv(path)
conteo = df["anio"].value_counts()
plt.barh( conteo.index, conteo)
plt.show()
# Out:
# <ipython-input-8-52c51c94c710>:4: DtypeWarning: Columns (14,19,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)

# %% [markdown]
# # Sección nueva

# %%
import pandas as pd
import matplotlib.pyplot as plt
path = "/content/drive/MyDrive/conjunto de datos/carlitos - atenciones_abogadas_de_las_mujeres (4).csv"
df = pd.read_csv(path)
edad = df ["anio_mes"]
dist = edad.value_counts()
plt.bar(dist.index, dist.values)
plt.xlim(0, 100)
plt.show()
# Out:
# <ipython-input-12-2faf6ff1a06c>:4: DtypeWarning: Columns (14,19,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)
